# %% [markdown]
# # Lab 2 Main: Data Manipulation
#
# Apply data wrangling skills to two datasets: `WeatherTrips.csv` and `products.csv`.
#
# Complete all questions and run the submission cells at the end.

# %%
import pandas as pd

# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab-02-main.ipynb")

# %% [markdown]
# ---
# ## Part 1: Warmup
#
# Complete these warmup questions to practice basic Pandas operations using the `WeatherTrips.csv` dataset, which contains daily bike trip counts and weather data.
#
# **Dataset Columns:**
# - `DATE` – Date of the observation
# - `NumTrips` – Number of bike trips that day
# - `PRCP` – Precipitation (inches)
# - `AWND` – Average wind speed
# - `TAVG` – Average temperature (°F)

# %% [markdown]
# ### Question 1: Loading
# Load the `WeatherTrips.csv` file into a DataFrame assigned to the variable `df`.

# %%
...

# %%
grader.check("q1")

# %% [markdown]
# ### Question 2: Filtering
# Create a new DataFrame called `warm_days` that only contains days where the average temperature (`TAVG`) is **50 degrees or higher**.

# %%
...

# %%
grader.check("q2")

# %% [markdown]
# ### Question 3: Sorting
# Assign the 5 days with the **highest** number of trips (`NumTrips`) to a new DataFrame called `busiest_days`.

# %%
...

# %%
grader.check("q3")

# %% [markdown]
# ### Question 4: Grouping & Aggregation
# First, create a new column called `MONTH` by extracting the first 7 characters from the `DATE` column (e.g., "2017-01").
#
# Then, calculate the **average number of trips** for each month. Assign the result (a Series) to `monthly_avg`.
#
# *Hint: To extract the first 7 characters from the `DATE` column, use `df["MONTH"] = df["DATE"].str[:7]`*

# %%
...

# %%
grader.check("q4")

# %% [markdown]
# ### Question 5: Pivot Table
# Create a Pivot Table that shows the **total number of trips** for each month:
# - Rows: `MONTH`
# - Values: `NumTrips` (sum)
#
# Assign this table to `monthly_totals`.
#
# *Hint: Use `pivot_table()` with `aggfunc='sum'`*

# %%
...

# %%
grader.check("q5")

# %% [markdown]
# ---
# ## Part 2: Main Questions
#
# Now apply the same skills to a new dataset: `products.csv`, which contains information about grocery store products.
#
# **Dataset Columns:**
# - `product_id` – Unique product identifier
# - `product_name` – Name of the product
# - `aisle_id` – Aisle identifier (which aisle the product is in)
# - `department_id` – Department identifier (which department the product belongs to)

# %% [markdown]
# ### Question 6: Loading
# Load the `products.csv` file into a DataFrame assigned to the variable `products`.

# %%
...

# %%
grader.check("q6")

# %% [markdown]
# ### Question 7: Filtering
# Create a new DataFrame called `dept_7` that only contains products from **department 7**.

# %%
...

# %%
grader.check("q7")

# %% [markdown]
# ### Question 8: Sorting
# Sort the DataFrame by `product_name` in **alphabetical order** (ascending). Assign the first 5 rows to a new DataFrame called `first_5_products`.

# %%
...

# %%
grader.check("q8")

# %% [markdown]
# ### Question 9: Grouping & Aggregation
# Count the **number of products** in each department (`department_id`). Assign the result (a Series) to `products_per_dept`.

# %%
...

# %%
grader.check("q9")

# %% [markdown]
# ### Question 10: Pivot Table
# Create a Pivot Table that shows the **count** of products for each department:
# - Rows: `department_id`
# - Values: `product_id` (count)
#
# Assign this table to `dept_totals`.
#
# *Hint: Use `pivot_table()` with `aggfunc='count'`*

# %%
...

# %%
grader.check("q10")

# %% [markdown]
# ---
# ## Submission
#
# Run the cells below to generate your submission ZIP file.

# %%
# !jupyter nbconvert --to script lab-02-main.ipynb

# %%
grader.export(pdf=False, force_save=True, run_tests=True, files=['lab-02-main.py'])
